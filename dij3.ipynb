# %%
from scipy.io import loadmat

# %%
dij=loadmat("dij.mat")

# %%
dij["dij2"][0]["doseGrid"][0]
# Out:
# array([[(array([[(array([[3]], dtype=uint8), array([[3]], dtype=uint8), array([[3]], dtype=uint8))]],
#               dtype=[('x', 'O'), ('y', 'O'), ('z', 'O')]), array([[-250, -247, -244, -241, -238, -235, -232, -229, -226, -223, -220,
#                 -217, -214, -211, -208, -205, -202, -199, -196, -193, -190, -187,
#                 -184, -181, -178, -175, -172, -169, -166, -163, -160, -157, -154,
#                 -151, -148, -145, -142, -139, -136, -133, -130, -127, -124, -121,
#                 -118, -115, -112, -109, -106, -103, -100,  -97,  -94,  -91,  -88,
#                  -85,  -82,  -79,  -76,  -73,  -70,  -67,  -64,  -61,  -58,  -55,
#                  -52,  -49,  -46,  -43,  -40,  -37,  -34,  -31,  -28,  -25,  -22,
#                  -19,  -16,  -13,  -10,   -7,   -4,   -1,    2,    5,    8,   11,
#                   14,   17,   20,   23,   26,   29,   32,   35,   38,   41,   44,
#                   47,   50,   53,   56,   59,   62,   65,   68,   71,   74,   77,
# ...

# %%
dij["dij2"][0][0][10]
# Out:
# array([[<2984123x3571 sparse matrix of type '<class 'numpy.float64'>'
#         	with 8267880 stored elements in Compressed Sparse Column format>]],
#       dtype=object)
